# %% [markdown]
# # **MÓDULO 39 - Exercicio - Aplicando SVM**

# %% [markdown]
# Nessa atividade vocês usarão uma base já connhecida, a base de propensão a compra de carros. A mesma que também usamos na tarefa de XGboost!

# %%
from sklearn.svm import SVC
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# **INFORMAÇÃO PAR SER INSERIDA NO README:**
#
# As etapas 1, 2, 3 e 4 seguiram o padrão da atividade realidada 'XGBoost LINK', já realizada, já que segue o mesmo processamente e a mesma base de dados, já o restante das etapas foram realizadas de forma singular já qeu o modelo desenvolvido é o SVM...

# %% [markdown]
# # 1. Carrega a base de dados, verifique os tipos de dados, dados faltantes e drop a coluna ID.

# %%
#SEU CÓDIGO AQUI

# %% [markdown]
# ## A) Carregamento da base de dados

# %%
# Carregamento da base de dados
base = pd.read_csv('CARRO_CLIENTES.csv', delimiter=',')

# Exibição da base
base
# Out:
#      User ID  Gender  Age  AnnualSalary  Purchased
# 0        385    Male   35         20000          0
# 1        681    Male   40         43500          0
# 2        353    Male   49         74000          0
# 3        895    Male   40        107500          1
# 4        661    Male   25         79000          0
# ..       ...     ...  ...           ...        ...
# 995      863    Male   38         59000          0
# 996      800  Female   47         23500          0
# 997      407  Female   28        138500          1
# 998      299  Female   48        134000          1
# 999      687  Female   44         73500          0
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## B) Verificação dos tipos de dados

# %%
# Verificação dos tipos de dados da base
base.dtypes
# Out:
# User ID          int64
# Gender          object
# Age              int64
# AnnualSalary     int64
# Purchased        int64
# dtype: object

# %% [markdown]
# A única variável categórica (**tipo object**) identificada na base é Gender. Para viabilizar o treinamento do SVM, que exige exclusivamente dados numéricos, essa coluna será processada via LabelEncoder posteriormente.

# %% [markdown]
# ## C) Verificação dos dados faltantes e tratamento

# %%
# Verificação dos valores nulos na base
base.isnull().sum()
# Out:
# User ID         0
# Gender          0
# Age             0
# AnnualSalary    0
# Purchased       0
# dtype: int64

# %% [markdown]
# Como a base de dados não apresenta valores nulos, a etapa de imputação ou eliminação de dados faltantes será dispensada, permitindo avançar para outros processo e etapdas.

# %% [markdown]
# ## D) Drop da coluna "User ID"

# %% [markdown]
# A exclusão da coluna `User ID` é necessária porque, embora seja do tipo numérico (**int**), ela representa apenas um identificador único do cliente. Por não carregar valor estatístico ou padrão comportamental, sua permanência geraria ruído desnecessário no treinamento do SVM.

# %%
# Exclusão da coluna 'User ID' da base
base = base.drop('User ID', axis=1)

# Exibição da base após a exclusão da coluna
base
# Out:
#      Gender  Age  AnnualSalary  Purchased
# 0      Male   35         20000          0
# 1      Male   40         43500          0
# 2      Male   49         74000          0
# 3      Male   40        107500          1
# 4      Male   25         79000          0
# ..      ...  ...           ...        ...
# 995    Male   38         59000          0
# 996  Female   47         23500          0
# 997  Female   28        138500          1
# 998  Female   48        134000          1
# 999  Female   44         73500          0
#
# [1000 rows x 4 columns]

# %% [markdown]
# # 2. Aplique o Label Encoder para a coluna Gender e exclua a coluna categórica.

# %%
#SEU CÓDIGO AQUI

# %% [markdown]
# # 3. Faça a matriz de correlação e analise as váriaveis que parecem ter maior correlação com a váriavel target.

# %%
#SEU CÓDIGO AQUI

# %% [markdown]
# # 4. Faça a separação da base em X e Y e em seguida nas bases de treino e teste.

# %%
#SEU CÓDIGO AQUI

# %% [markdown]
# **Todos passos até aqui vocês realizaram na tarefa anterior também!**

# %% [markdown]
# # 5. Treino o modelo SVM com sua base de treino.
# Esse modelo deve ser treinado usando o kernel linear.

# %%
#SEU CÓDIGO AQUI

# %% [markdown]
# # 6. Realize as previsões para a base de teste e traga a avaliação.

# %%
#SEU CÓDIGO AQUI

# %% [markdown]
# # 7. Treine um novo modelo SVM com sua base de treino + realize as previsões e avalições.
# Esse modelo dedve ser treinado usando o kernel poly.

# %%
#SEU CÓDIGO AQUI

# %% [markdown]
# # 8. Qual modelo se saiu melhor? O SVM com kernel linear ou poly? Compare também com o XGboost, da atividade anterior, você obteve melhores previsões com qual dos modelos?
